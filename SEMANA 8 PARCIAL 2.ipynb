# %%
# !pip install matplotlib mysql-connector-python openpyxl

# %%
import subprocess
import re
import mysql.connector
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

# %%
# Funcion para medir el ping a través de un subproceso

def medir_ping(host,count):
    ping_output = subprocess.run(
        ["ping", "-c",str(count), host],capture_output=True,text=True
    )

    ping_times = re.findall(r"time=(\d+\.\d+)",ping_output.stdout)
    
    return list(map(float,ping_times))


#tiempo_ping = medir_ping(host_test,10)
#[22.401, 18.037, 17.588, 36.65, 17.619, 20.051, 17.688, 20.033, 17.613, 22.042]

# %%
# Función para graficar el tiempo

def graficar_ping(ping_times):
    plt.plot(ping_times)
    plt.title("Ping a Google")
    plt.xlabel("Número de ping")
    plt.ylabel("Tiempo de respuesta (ms)")
    plt.show()

# %%
# Función para insertar datos en la base de datos mysql
def insertar_en_mysql(host, ping_times):
    conn = mysql.connector.connect(
        host="localhost", 
        user="root", 
        password="root", 
        database="diccionario_db"
    )

    cursor = conn.cursor()

    cursor.execute("CREATE TABLE IF NOT EXISTS ping_data (id_ping_data INT AUTO_INCREMENT PRIMARY KEY, timestamp DATETIME, host VARCHAR(255), ping_time FLOAT)")

    # Insertar datos en la base de datos

    for ping_time in ping_times:
        timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        insert_query = ("INSERT INTO ping_data (timestamp,host,ping_time) VALUES (%s,%s,%s)")

        cursor.execute(insert_query,(timestamp,host,ping_time))

    conn.commit()
    cursor.close()
    conn.close()

# %%
# Función para crear el excel

def crear_excel(ping_times):
    df = pd.DataFrame({"Ping":ping_times})
    df.to_excel("ping_data.xlsx", index=False)

# %%
# Configuración
host = "google.com"
ping_count = 10

# %%
# Funciones ejecutadas

#medir ping
ping_times = medir_ping(host,ping_count)

# graficar ping
graficar_ping(ping_times)

# insertar a la base de datos
insertar_en_mysql(host,ping_times)

# crear EXCEl

crear_excel(ping_times)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/mysql/connector/conversion.py:179, in MySQLConverter.to_mysql(self, value)
#     178 try:
# --> 179     return getattr(self, "_{0}_to_mysql".format(type_name))(value)
#     180 except AttributeError:
#
# AttributeError: 'MySQLConverter' object has no attribute '_list_to_mysql'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/mysql/connector/cursor.py:417, in MySQLCursor._process_params(self, params)
#     415 quote = self._connection.converter.quote
# --> 417 res = [to_mysql(i) for i in res]
#     418 res = [escape(i) for i in res]
#
# File ~/anaconda3/lib/python3.11/site-packages/mysql/connector/cursor.py:417, in <listcomp>(.0)
#     415 quote = self._connection.converter.quote
# --> 417 res = [to_mysql(i) for i in res]
#     418 res = [escape(i) for i in res]
#
# File ~/anaconda3/lib/python3.11/site-packages/mysql/connector/conversion.py:181, in MySQLConverter.to_mysql(self, value)
#     180 except AttributeError:
# --> 181     raise TypeError("Python '{0}' cannot be converted to a "
#     182                     "MySQL type".format(type_name))
#
# TypeError: Python 'list' cannot be converted to a MySQL type
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[11], line 10
#       7 graficar_ping(ping_times)
#       9 # insertar a la base de datos
# ---> 10 insertar_en_mysql(host,ping_times)
#      12 # crear EXCEl
#      14 crear_excel(ping_times)
#
# Cell In[10], line 20, in insertar_en_mysql(host, ping_times)
#      17     timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
#      18     insert_query = ("INSERT INTO ping_data (timestamp,host,ping_time) VALUES (%s,%s,%s)")
# ---> 20     cursor.execute(insert_query,(timestamp,host,ping_times))
#      22 conn.commit()
#      23 cursor.close()
#
# File ~/anaconda3/lib/python3.11/site-packages/mysql/connector/cursor.py:539, in MySQLCursor.execute(self, operation, params, multi)
#     536     stmt = _bytestr_format_dict(
#     537         stmt, self._process_params_dict(params))
#     538 elif isinstance(params, (list, tuple)):
# --> 539     psub = _ParamSubstitutor(self._process_params(params))
#     540     stmt = RE_PY_PARAM.sub(psub, stmt)
#     541     if psub.remaining != 0:
#
# File ~/anaconda3/lib/python3.11/site-packages/mysql/connector/cursor.py:421, in MySQLCursor._process_params(self, params)
#     419     res = [quote(i) for i in res]
#     420 except Exception as err:
# --> 421     raise errors.ProgrammingError(
#     422         "Failed processing format-parameters; %s" % err)
#     423 else:
#     424     return tuple(res)
#
# ProgrammingError: Failed processing format-parameters; Python 'list' cannot be converted to a MySQL type
